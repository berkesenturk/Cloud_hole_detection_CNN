# %%
import xarray as xr
import matplotlib.pyplot as plt

path = '/mnt/ls03-data/JF/urban_cloud/data/SEVIRI_Paris/results/'
hrv_data = xr.open_dataset(path + 'hrv_lr201501.nc')

# %%
hrv_data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1016, y: 92, x: 109)
# Coordinates:
#     lat      (y, x) float64 ...
#     lon      (y, x) float64 ...
#   * time     (time) datetime64[ns] 2015-01-01T08:00:00 ... 2015-01-31T16:00:00
# Dimensions without coordinates: y, x
# Data variables:
#     hrv      (time, y, x) float64 ...

# %%
cmap = plt.get_cmap('Greys_r')#
im = hrv_data.hrv.sel(time='2015-01-17T09:00:00').plot.pcolormesh('lon', 'lat', cmap=cmap,robust=True, add_labels=False,cbar_kwargs={"label": "reflectance","pad": 0.04,"shrink":0.75,"aspect": 20,"extend":"both","format":"%0.1f"})
